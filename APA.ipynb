# %% [markdown]
# # Tool for generating possible APA teams.

# %%
team = [
    ("Victoria", 4, 3),
    ("John",     6, 8),
    ("Sam",      4, 3),
    ("Josh",     4, 4),
    ("Peggy",    2, 2),
    ("Richie",   7, 7),
    ("Charlie",  4, 4),
    ("Jessie",   2, 2),
]

# %%
import pandas as pd
from itertools import combinations

def possible_team(team_data, game, min_skill, max_skill):
    """
    Generates a Pandas DataFrame of all possible team lineups based on given criteria.
    
    Args:
    team_data: A list of tuples, each containing (name, 8-ball skill, 9-ball skill).
    game: An integer, 8 for 8-ball, otherwise 9-ball.
    min_skill: The minimum combined skill level for a valid team.
    max_skill: The maximum combined skill level for a valid team.
    
    Returns:
    A Pandas DataFrame containing all possible team lineups.
    """
    
    skill_index = 1 if game == 8 else 2  # Index for relevant skill level
    all_teams = []
    for team in combinations(team_data, 5):
        total_skill = sum([player[skill_index] for player in team])
        if min_skill <= total_skill <= max_skill:
            sorted_team = sorted(team, key=lambda x: (-x[skill_index], x[0])) # Sort by skill descending, then name ascending
            team_row = []
            for player in sorted_team:
                team_row.extend([player[0], player[skill_index]])
            team_row.append(total_skill)  # Add total skill at the end
            all_teams.append(team_row)
    
    columns = [f"Player{(i // 2)+1}" if (i+1) % 2 else f"Skill{i//2 + 1}" for i in range(10)] + ["Team Skill"]
    df = pd.DataFrame(all_teams, columns=columns)
    df = df.sort_values(by=[f"Skill{i}" for i in range(1, 6)], ascending=[False]*5) # Sort by skills
    df = df.reset_index(drop=True)
    return df

# %%
possible_team(team, 8, 0, 23)
# Out:
#     Player1  Skill1  Player2  Skill2   Player3  Skill3   Player4  Skill4  \
# 0    Richie       7     John       6       Sam       4  Victoria       4
# 1    Richie       7     John       6       Sam       4  Victoria       4
# 2    Richie       7     John       6      Josh       4  Victoria       4
# 3    Richie       7     John       6      Josh       4  Victoria       4
# 4    Richie       7     John       6   Charlie       4  Victoria       4
# 5    Richie       7     John       6   Charlie       4  Victoria       4
# 6    Richie       7     John       6      Josh       4       Sam       4
# 7    Richie       7     John       6      Josh       4       Sam       4
# 8    Richie       7     John       6   Charlie       4       Sam       4
# 9    Richie       7     John       6   Charlie       4       Sam       4
# 10   Richie       7     John       6   Charlie       4      Josh       4
# 11   Richie       7     John       6   Charlie       4      Josh       4
# 12   Richie       7     John       6  Victoria       4    Jessie       2
# 13   Richie       7     John       6       Sam       4    Jessie       2
# 14   Richie       7     John       6      Josh       4    Jessie       2
# 15   Richie       7     John       6   Charlie       4    Jessie       2
# 16   Richie       7  Charlie       4      Josh       4       Sam       4
# 17   Richie       7     Josh       4       Sam       4  Victoria       4
# 18   Richie       7     Josh       4       Sam       4  Victoria       4
# 19   Richie       7  Charlie       4       Sam       4  Victoria       4
# 20   Richie       7  Charlie       4       Sam       4  Victoria       4
# 21   Richie       7  Charlie       4      Josh       4  Victoria       4
# 22   Richie       7  Charlie       4      Josh       4  Victoria       4
# 23   Richie       7  Charlie       4      Josh       4       Sam       4
# 24   Richie       7  Charlie       4      Josh       4       Sam       4
# 25   Richie       7      Sam       4  Victoria       4    Jessie       2
# 26   Richie       7     Josh       4  Victoria       4    Jessie       2
# 27   Richie       7  Charlie       4  Victoria       4    Jessie       2
# 28   Richie       7     Josh       4       Sam       4    Jessie       2
# 29   Richie       7  Charlie       4       Sam       4    Jessie       2
# 30   Richie       7  Charlie       4      Josh       4    Jessie       2
# 31     John       6  Charlie       4      Josh       4       Sam       4
# 32     John       6     Josh       4       Sam       4  Victoria       4
# 33     John       6     Josh       4       Sam       4  Victoria       4
# 34     John       6  Charlie       4       Sam       4  Victoria       4
# 35     John       6  Charlie       4       Sam       4  Victoria       4
# 36     John       6  Charlie       4      Josh       4  Victoria       4
# 37     John       6  Charlie       4      Josh       4  Victoria       4
# 38     John       6  Charlie       4      Josh       4       Sam       4
# 39     John       6  Charlie       4      Josh       4       Sam       4
# 40     John       6      Sam       4  Victoria       4    Jessie       2
# 41     John       6     Josh       4  Victoria       4    Jessie       2
# 42     John       6  Charlie       4  Victoria       4    Jessie       2
# 43     John       6     Josh       4       Sam       4    Jessie       2
# 44     John       6  Charlie       4       Sam       4    Jessie       2
# 45     John       6  Charlie       4      Josh       4    Jessie       2
# 46  Charlie       4     Josh       4       Sam       4  Victoria       4
# 47  Charlie       4     Josh       4       Sam       4  Victoria       4
# 48     Josh       4      Sam       4  Victoria       4    Jessie       2
# 49  Charlie       4      Sam       4  Victoria       4    Jessie       2
# 50  Charlie       4     Josh       4  Victoria       4    Jessie       2
# 51  Charlie       4     Josh       4       Sam       4    Jessie       2
#
#      Player5  Skill5  Team Skill
# 0      Peggy       2          23
# 1     Jessie       2          23
# 2      Peggy       2          23
# 3     Jessie       2          23
# 4      Peggy       2          23
# 5     Jessie       2          23
# 6      Peggy       2          23
# 7     Jessie       2          23
# 8      Peggy       2          23
# 9     Jessie       2          23
# 10     Peggy       2          23
# 11    Jessie       2          23
# 12     Peggy       2          21
# 13     Peggy       2          21
# 14     Peggy       2          21
# 15     Peggy       2          21
# 16  Victoria       4          23
# 17     Peggy       2          21
# 18    Jessie       2          21
# 19     Peggy       2          21
# 20    Jessie       2          21
# 21     Peggy       2          21
# 22    Jessie       2          21
# 23     Peggy       2          21
# 24    Jessie       2          21
# 25     Peggy       2          19
# 26     Peggy       2          19
# 27     Peggy       2          19
# 28     Peggy       2          19
# 29     Peggy       2          19
# 30     Peggy       2          19
# 31  Victoria       4          22
# 32     Peggy       2          20
# 33    Jessie       2          20
# 34     Peggy       2          20
# 35    Jessie       2          20
# 36     Peggy       2          20
# 37    Jessie       2          20
# 38     Peggy       2          20
# 39    Jessie       2          20
# 40     Peggy       2          18
# 41     Peggy       2          18
# 42     Peggy       2          18
# 43     Peggy       2          18
# 44     Peggy       2          18
# 45     Peggy       2          18
# 46     Peggy       2          18
# 47    Jessie       2          18
# 48     Peggy       2          16
# 49     Peggy       2          16
# 50     Peggy       2          16
# 51     Peggy       2          16

# %%
possible_team(team, 9, 0, 23)
# Out:
#     Player1  Skill1  Player2  Skill2   Player3  Skill3   Player4  Skill4  \
# 0      John       8   Richie       7      Josh       4    Jessie       2
# 1      John       8   Richie       7   Charlie       4    Jessie       2
# 2      John       8   Richie       7       Sam       3  Victoria       3
# 3      John       8   Richie       7       Sam       3  Victoria       3
# 4      John       8   Richie       7  Victoria       3    Jessie       2
# 5      John       8   Richie       7       Sam       3    Jessie       2
# 6      John       8  Charlie       4      Josh       4       Sam       3
# 7      John       8  Charlie       4      Josh       4  Victoria       3
# 8      John       8  Charlie       4      Josh       4  Victoria       3
# 9      John       8  Charlie       4      Josh       4       Sam       3
# 10     John       8  Charlie       4      Josh       4       Sam       3
# 11     John       8  Charlie       4      Josh       4    Jessie       2
# 12     John       8     Josh       4       Sam       3  Victoria       3
# 13     John       8     Josh       4       Sam       3  Victoria       3
# 14     John       8  Charlie       4       Sam       3  Victoria       3
# 15     John       8  Charlie       4       Sam       3  Victoria       3
# 16     John       8     Josh       4  Victoria       3    Jessie       2
# 17     John       8  Charlie       4  Victoria       3    Jessie       2
# 18     John       8     Josh       4       Sam       3    Jessie       2
# 19     John       8  Charlie       4       Sam       3    Jessie       2
# 20     John       8      Sam       3  Victoria       3    Jessie       2
# 21   Richie       7  Charlie       4      Josh       4       Sam       3
# 22   Richie       7  Charlie       4      Josh       4  Victoria       3
# 23   Richie       7  Charlie       4      Josh       4  Victoria       3
# 24   Richie       7  Charlie       4      Josh       4       Sam       3
# 25   Richie       7  Charlie       4      Josh       4       Sam       3
# 26   Richie       7  Charlie       4      Josh       4    Jessie       2
# 27   Richie       7     Josh       4       Sam       3  Victoria       3
# 28   Richie       7     Josh       4       Sam       3  Victoria       3
# 29   Richie       7  Charlie       4       Sam       3  Victoria       3
# 30   Richie       7  Charlie       4       Sam       3  Victoria       3
# 31   Richie       7     Josh       4  Victoria       3    Jessie       2
# 32   Richie       7  Charlie       4  Victoria       3    Jessie       2
# 33   Richie       7     Josh       4       Sam       3    Jessie       2
# 34   Richie       7  Charlie       4       Sam       3    Jessie       2
# 35   Richie       7      Sam       3  Victoria       3    Jessie       2
# 36  Charlie       4     Josh       4       Sam       3  Victoria       3
# 37  Charlie       4     Josh       4       Sam       3  Victoria       3
# 38  Charlie       4     Josh       4  Victoria       3    Jessie       2
# 39  Charlie       4     Josh       4       Sam       3    Jessie       2
# 40     Josh       4      Sam       3  Victoria       3    Jessie       2
# 41  Charlie       4      Sam       3  Victoria       3    Jessie       2
#
#      Player5  Skill5  Team Skill
# 0      Peggy       2          23
# 1      Peggy       2          23
# 2      Peggy       2          23
# 3     Jessie       2          23
# 4      Peggy       2          22
# 5      Peggy       2          22
# 6   Victoria       3          22
# 7      Peggy       2          21
# 8     Jessie       2          21
# 9      Peggy       2          21
# 10    Jessie       2          21
# 11     Peggy       2          20
# 12     Peggy       2          20
# 13    Jessie       2          20
# 14     Peggy       2          20
# 15    Jessie       2          20
# 16     Peggy       2          19
# 17     Peggy       2          19
# 18     Peggy       2          19
# 19     Peggy       2          19
# 20     Peggy       2          18
# 21  Victoria       3          21
# 22     Peggy       2          20
# 23    Jessie       2          20
# 24     Peggy       2          20
# 25    Jessie       2          20
# 26     Peggy       2          19
# 27     Peggy       2          19
# 28    Jessie       2          19
# 29     Peggy       2          19
# 30    Jessie       2          19
# 31     Peggy       2          18
# 32     Peggy       2          18
# 33     Peggy       2          18
# 34     Peggy       2          18
# 35     Peggy       2          17
# 36     Peggy       2          16
# 37    Jessie       2          16
# 38     Peggy       2          15
# 39     Peggy       2          15
# 40     Peggy       2          14
# 41     Peggy       2          14
